# %%
# !pip install pytest

# %%
# %env PYTHONDONTWRITEBYTECODE=1

# %%
import sys
sys.dont_write_bytecode = True

# %%
import pytest
import sys
sys.dont_write_bytecode = True
pytest.main(["tests", "-v"])

# %%
# %python
import pytest
import sys
sys.dont_write_bytecode = True
pytest.main(["tests/test_bronze.py", "-v"])

# %%
# %python
import pytest
import sys
sys.dont_write_bytecode = True
pytest.main(["tests/test_full_pipeline.py", "-v"])

# %%
# %python
import pytest
import sys
sys.dont_write_bytecode = True
pytest.main(["tests/test_schema.py", "-v"])

# %%
import pytest
import sys
# importlib.reload(pytest)
sys.dont_write_bytecode = True
pytest.main(["tests/test_silver_enrichment.py", "-v"])

# %%
import pytest
import sys
# importlib.reload(pytest)
sys.dont_write_bytecode = True
pytest.main(["tests/test_silver_validation.py", "-v"])
